# %%
x=1.9
y=1.6
r=1.2
theta <- seq(-pi, pi, length=100)
plot(c(-3,3), c(-3,3), type="n", asp=1) 
points(0 + 2*cos(theta), -1 + 2*sin(theta), type="l", asp=1)
points(-x + r*cos(theta), y + r*sin(theta), type="l", asp=1)
points(x + r*cos(theta), y + r*sin(theta), type="l", asp=1)
# Out:
# plot without title
